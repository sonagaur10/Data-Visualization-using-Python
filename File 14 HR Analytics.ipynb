# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
os.chdir("C:\\Users\\user\\Desktop\\Python files")

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '14 -HRAnalytics.csv',
#  'adult.data',
#  'adult.names',
#  'advertising_2.csv',
#  'BankChurners.csv',
#  'Basic.txt',
#  'Churn_Modelling.csv.txt',
#  'Class18_Altairnotebook.ipynb',
#  'Class18_geograhic data.ipynb',
#  'co2.csv',
#  'delhi_weather_data.zip',
#  'ETH_1h.csv',
#  'gapminder.csv',
#  'hpi_data_countries.tsv',
#  'IPL IMB381IPL2013.csv',
#  'Lecture18_DEVP.ipynb',
#  'python 2.txt',
#  'Python files-checkpoint.ipynb',
#  'Python files.ipynb',
#  'pythone code session 10.txt',
#  'session 4.ipynb',
#  'share-of-individuals-using-the-internet.csv']

# %%
df=pd.read_csv("14 -HRAnalytics.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df.shape
# Out:
# (4410, 24)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df.JobRole.unique()
# Out:
# array(['Healthcare Representative', 'Research Scientist',
#        'Sales Executive', 'Human Resources', 'Research Director',
#        'Laboratory Technician', 'Manufacturing Director',
#        'Sales Representative', 'Manager'], dtype=object)

# %%
df.JobLevel.unique()
# Out:
# array([1, 4, 3, 2, 5], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
df.groupby('JobRole')['PercentSalaryHike'].mean()
# Out:
# JobRole
# Healthcare Representative    15.442748
# Human Resources              14.538462
# Laboratory Technician        15.521236
# Manager                      15.166667
# Manufacturing Director       15.013793
# Research Director            15.062500
# Research Scientist           15.136986
# Sales Executive              14.923313
# Sales Representative         16.204819
# Name: PercentSalaryHike, dtype: float64

# %%
df.groupby('JobLevel')['MonthlyIncome'].mean()
# Out:
# JobLevel
# 1    62677.421731
# 2    65506.479401
# 3    63545.321101
# 4    77940.754717
# 5    64698.405797
# Name: MonthlyIncome, dtype: float64

# %%
df.groupby('Department')['MonthlyIncome'].mean()
# Out:
# Department
# Human Resources           57904.444444
# Research & Development    67187.960458
# Sales                     61384.484305
# Name: MonthlyIncome, dtype: float64

# %%
df[['Department','EducationField','JobRole']][:5]
# Out:
#                Department EducationField                    JobRole
# 0                   Sales  Life Sciences  Healthcare Representative
# 1  Research & Development  Life Sciences         Research Scientist
# 2  Research & Development          Other            Sales Executive
# 3  Research & Development  Life Sciences            Human Resources
# 4  Research & Development        Medical            Sales Executive

# %%
df.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
df.drop('StockOptionLevel',inplace=True,axis=1)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    MonthlyIncome NumCompaniesWorked Over18  PercentSalaryHike  StandardHours  \
# ...

# %%
sns.barplot(x='Department',y='JobLevel',data=df)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='JobLevel'>

# %%
sns.kdeplot(df.Age)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.barplot(x='Department',y='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Age'>

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='JobRole',y='YearsSinceLastPromotion',hue='Attrition',data=df)
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='YearsSinceLastPromotion'>

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x='JobRole',y='PercentSalaryHike',hue='Attrition',data=df)
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='PercentSalaryHike'>

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x='JobRole',y='YearsAtCompany',hue='Attrition',data=df)
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='YearsAtCompany'>

# %%
sns.barplot(x='Attrition',y='YearsAtCompany',hue='Gender',data=df,estimator=np.median)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='YearsAtCompany'>

# %%
sns.barplot(x='Attrition',y='PercentSalaryHike',data=df)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='PercentSalaryHike'>

# %%
sns.barplot(x='JobLevel',y='YearsAtCompany',hue='Attrition',data=df,estimator=np.median)
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='YearsAtCompany'>

# %%
sns.barplot(x='Attrition',y='PercentSalaryHike',hue='Gender',data=df,estimator=np.median)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='PercentSalaryHike'>

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    MonthlyIncome NumCompaniesWorked Over18  PercentSalaryHike  StandardHours  \
# ...

# %%
cross1=pd.crosstab(df.JobRole,df.EducationField)

# %%
cross1
# Out:
# EducationField             Human Resources  Life Sciences  Marketing  Medical  \
# JobRole
# Healthcare Representative                3            174         30      117
# Human Resources                          0             63         21       48
# Laboratory Technician                   21            309         99      246
# Manager                                  9            138         24       90
# Manufacturing Director                  12            195         36      123
# Research Director                        3            105         36       60
# Research Scientist                      12            357        102      300
# Sales Executive                         15            381        108      318
# Sales Representative                     6             96         21       90
#
# EducationField             Other  Technical Degree
# JobRole
# Healthcare Representative     24                45
# Human Resources               12                12
# ...

# %%
sns.heatmap(cross1,annot=True,cmap='Greens')
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='JobRole'>

# %%
plt.figure(figsize=(15,8))
sns.violinplot(x='JobRole',y='DistanceFromHome',hue='Attrition',data=df,split=True)
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='DistanceFromHome'>

# %%
plt.figure(figsize=(15,8))
sns.violinplot(x='JobRole',y='PercentSalaryHike',hue='Attrition',data=df,split=True)
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='PercentSalaryHike'>

# %%
plt.figure(figsize=(15,8))
sns.barplot(x='JobRole',y='YearsWithCurrManager',hue='Attrition',data=df)
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='YearsWithCurrManager'>

# %%
df.Attrition=df.Attrition.map({'No':0,'Yes':1})

# %%
df.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  MonthlyIncome NumCompaniesWorked Over18  PercentSalaryHike  \
# 0  Female  ...         131160                1.0      Y                 11
# ...

# %%
dt=df.select_dtypes(include=['float64','int64'])

# %%
dt.head()
# Out:
#    Age  Attrition  DistanceFromHome  Education  EmployeeCount  EmployeeID  \
# 0   51          0                 6          2              1           1
# 1   31          1                10          1              1           2
# 2   32          0                17          4              1           3
# 3   38          0                 2          5              1           4
# 4   32          0                10          1              1           5
#
#    JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# 0         1         131160                 1.0                 11
# 1         1          41890                 0.0                 23
# 2         4         193280                 1.0                 15
# 3         3          83210                 3.0                 11
# 4         1          23420                 4.0                 12
#
#    StandardHours  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# ...

# %%
pd.plotting.parallel_coordinates(dt,class_column='Attrition',color=('red','blue'))
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
ss.fit(dt)
# Out:
# StandardScaler()

# %%
x=ss.transform(dt)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
df1=pd.DataFrame(x,columns=dt.columns)

# %%
df1.head()
# Out:
#         Age  Attrition  DistanceFromHome  Education  EmployeeCount  \
# 0  1.541369  -0.438422         -0.393938  -0.891688            0.0
# 1 -0.648668   2.280906          0.099639  -1.868426            0.0
# 2 -0.539166  -0.438422          0.963398   1.061787            0.0
# 3  0.117845  -0.438422         -0.887515   2.038524            0.0
# 4 -0.539166  -0.438422          0.099639  -1.868426            0.0
#
#    EmployeeID  JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# 0   -1.731658 -0.961486       1.405136           -0.678311          -1.150554
# 1   -1.730873 -0.961486      -0.491661           -1.078535           2.129306
# 2   -1.730087  1.749610       2.725053           -0.678311          -0.057267
# 3   -1.729302  0.845911       0.386301            0.122136          -1.150554
# 4   -1.728516 -0.961486      -0.884109            0.522360          -0.877232
#
#    StandardHours  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# ...

# %%
df1.Attrition=dt.Attrition

# %%
df1.head()
# Out:
#         Age  Attrition  DistanceFromHome  Education  EmployeeCount  \
# 0  1.541369          0         -0.393938  -0.891688            0.0
# 1 -0.648668          1          0.099639  -1.868426            0.0
# 2 -0.539166          0          0.963398   1.061787            0.0
# 3  0.117845          0         -0.887515   2.038524            0.0
# 4 -0.539166          0          0.099639  -1.868426            0.0
#
#    EmployeeID  JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# 0   -1.731658 -0.961486       1.405136           -0.678311          -1.150554
# 1   -1.730873 -0.961486      -0.491661           -1.078535           2.129306
# 2   -1.730087  1.749610       2.725053           -0.678311          -0.057267
# 3   -1.729302  0.845911       0.386301            0.122136          -1.150554
# 4   -1.728516 -0.961486      -0.884109            0.522360          -0.877232
#
#    StandardHours  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# ...

# %%
pd.plotting.parallel_coordinates(df1,class_column='Attrition',color=('red','blue'))
# Out:
# <AxesSubplot:>

# %%
pd.plotting.andrews_curves(df1,class_column='Attrition',color=('red','blue'))
# Out:
# <AxesSubplot:>

# %%
pip install altair vega_datasets

# %%
import altair as alt

# %%
alt.Chart(df).mark_bar().encode(
x='JobRole',
y='YearsSinceLastPromotion',
).properties(width=400).interactive()
# Out:
# alt.Chart(...)
