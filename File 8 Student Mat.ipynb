# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
os.chdir("C:\\Users\\user\\Desktop\\Python files")

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '14 -HRAnalytics.csv',
#  '8-student-mat.csv',
#  'adult.data',
#  'adult.names',
#  'advertising_2.csv',
#  'BankChurners.csv',
#  'Basic.txt',
#  'Churn_Modelling.csv.txt',
#  'Class18_Altairnotebook.ipynb',
#  'Class18_geograhic data.ipynb',
#  'co2.csv',
#  'delhi_weather_data.zip',
#  'ETH_1h.csv',
#  'gapminder.csv',
#  'hpi_data_countries.tsv',
#  'IPL IMB381IPL2013.csv',
#  'Lecture18_DEVP.ipynb',
#  'python 2.txt',
#  'Python files-checkpoint.ipynb',
#  'Python files.ipynb',
#  'pythone code session 10.txt',
#  'session 4.ipynb',
#  'share-of-individuals-using-the-internet.csv']

# %%
df=pd.read_csv("8-student-mat.csv")

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (395, 33)

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.reason.unique()
# Out:
# array(['course', 'other', 'home', 'reputation'], dtype=object)

# %%
df.romantic.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df.failures.unique()
# Out:
# array([0, 3, 2, 1], dtype=int64)

# %%
df['school'].value_counts()
# Out:
# GP    349
# MS     46
# Name: school, dtype: int64

# %%
df[['school','G3']].groupby(df['school']).mean()
# Out:
#                G3
# school
# GP      10.489971
# MS       9.847826

# %%
sns.catplot(x="school",y="G3", kind="box",data=df)

# %%
sns.boxplot(x="sex",y="G3",data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='G3'>

# %%
sns.barplot(x="age",y="G3",data=df,hue='address')
# Out:
# <AxesSubplot:xlabel='age', ylabel='G3'>

# %%
df.studytime.unique()
# Out:
# array([2, 3, 1, 4], dtype=int64)

# %%
sns.barplot(x="address",y="studytime",data=df)
# Out:
# <AxesSubplot:xlabel='address', ylabel='studytime'>

# %%
sns.catplot(x="famsize",y="G3", kind="box",data=df)

# %%
sns.boxplot(x="Medu",y="G3",data=df)
# Out:
# <AxesSubplot:xlabel='Medu', ylabel='G3'>

# %%
sns.boxplot(x="Fedu",y="G3",data=df)
# Out:
# <AxesSubplot:xlabel='Fedu', ylabel='G3'>

# %%
df[df['G3']<10][['school','Pstatus','studytime','activities','traveltime']]
# Out:
#     school Pstatus  studytime activities  traveltime
# 0       GP       A          2         no           2
# 1       GP       T          2         no           1
# 7       GP       A          2         no           2
# 10      GP       T          2         no           1
# 18      GP       T          1        yes           1
# ..     ...     ...        ...        ...         ...
# 388     MS       T          2         no           1
# 389     MS       T          2        yes           2
# 390     MS       A          2         no           1
# 392     MS       T          1         no           1
# 394     MS       T          1         no           1
#
# [130 rows x 5 columns]

# %%
sns.violinplot(x='romantic',y='G3',hue='address',data=df,split=True)
# Out:
# <AxesSubplot:xlabel='romantic', ylabel='G3'>

# %%
sns.violinplot(x='romantic',y='G3',hue='sex',data=df,split=True)
# Out:
# <AxesSubplot:xlabel='romantic', ylabel='G3'>

# %%
sns.violinplot(x='health',y='G3',hue='sex',data=df,split=True)
# Out:
# <AxesSubplot:xlabel='health', ylabel='G3'>

# %%
dt=df.select_dtypes(include=['float64','int64'])

# %%
dt
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0     18     4     4           2          2         0       4         3
# 1     17     1     1           1          2         0       5         3
# 2     15     1     1           1          2         3       4         3
# 3     15     4     2           1          3         0       3         2
# 4     16     3     3           1          2         0       4         3
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 390   20     2     2           1          2         2       5         5
# 391   17     3     1           2          1         0       2         4
# 392   21     1     1           1          1         3       5         5
# 393   18     3     2           3          1         0       4         4
# 394   19     1     1           1          1         0       3         2
#
#      goout  Dalc  Walc  health  absences  G1  G2  G3
# ...

# %%
pd.plotting.parallel_coordinates(dt,class_column='G3',color=('red','blue'))
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
ss.fit(dt)
# Out:
# StandardScaler()

# %%
x=ss.transform(dt)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
df1=pd.DataFrame(x,columns=dt.columns)

# %%
df1.head()
# Out:
#         age      Medu      Fedu  traveltime  studytime  failures    famrel  \
# 0  1.023046  1.143856  1.360371    0.792251  -0.042286 -0.449944  0.062194
# 1  0.238380 -1.600009 -1.399970   -0.643249  -0.042286 -0.449944  1.178860
# 2 -1.330954 -1.600009 -1.399970   -0.643249  -0.042286  3.589323  0.062194
# 3 -1.330954  1.143856 -0.479857   -0.643249   1.150779 -0.449944 -1.054472
# 4 -0.546287  0.229234  0.440257   -0.643249  -0.042286 -0.449944  0.062194
#
#    freetime     goout      Dalc      Walc    health  absences        G1  \
# 0 -0.236010  0.801479 -0.540699 -1.003789 -0.399289  0.036424 -1.782467
# 1 -0.236010 -0.097908 -0.540699 -1.003789 -0.399289 -0.213796 -1.782467
# 2 -0.236010 -0.997295  0.583385  0.551100 -0.399289  0.536865 -1.179147
# 3 -1.238419 -0.997295 -0.540699 -1.003789  1.041070 -0.464016  1.234133
# 4 -0.236010 -0.997295 -0.540699 -0.226345  1.041070 -0.213796 -1.480807
#
#          G2        G3
# 0 -1.254791 -0.964934
# 1 -1.520979 -0.964934
# ...

# %%
df1.G3=dt.G3

# %%
pd.plotting.parallel_coordinates(df1,class_column='G3',color=('red','blue'))
# Out:
# <AxesSubplot:>

# %%
pd.plotting.andrews_curves(df1,class_column='G3',color=('red','blue'))
# Out:
# <AxesSubplot:>

# %%
df['G3_CUT']=pd.cut(df.G3,bins=2,labels=['P','F'])

# %%
# Out:
# 0      P
# 1      P
# 2      P
# 3      F
# 4      P
#       ..
# 390    P
# 391    F
# 392    P
# 393    P
# 394    P
# Name: G3_CUT, Length: 395, dtype: category
# Categories (2, object): ['P' < 'F']

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3 G3_CUT
# 0        3     4     1     1       3        6   5   6   6      P
# 1        3     3     1     1       3        4   5   5   6      P
# 2        3     2     2     3       3       10   7   8  10      P
# 3        2     2     1     1       5        2  15  14  15      F
# 4        3     2     1     2       5        4   6  10  10      P
#
# [5 rows x 34 columns]

# %%
df.G3_CUT=df.G3_CUT.map({'P':0,'F':1})

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3 G3_CUT
# 0        3     4     1     1       3        6   5   6   6      0
# 1        3     3     1     1       3        4   5   5   6      0
# 2        3     2     2     3       3       10   7   8  10      0
# 3        2     2     1     1       5        2  15  14  15      1
# 4        3     2     1     2       5        4   6  10  10      0
#
# [5 rows x 34 columns]

# %%
dt=df.select_dtypes(include=['float64','int64','category'])

# %%
dt.head()
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  Walc  health  absences  G1  G2  G3 G3_CUT
# 0     1     1       3         6   5   6   6      0
# 1     1     1       3         4   5   5   6      0
# 2     2     3       3        10   7   8  10      0
# 3     1     1       5         2  15  14  15      1
# 4     1     2       5         4   6  10  10      0

# %%
pd.plotting.parallel_coordinates(dt,class_column='G3_CUT',color=('red','blue'))
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
ss.fit(dt)
# Out:
# StandardScaler()

# %%
x=ss.transform(dt)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
df1=pd.DataFrame(x,columns=dt.columns)

# %%
df1.head()
# Out:
#         age      Medu      Fedu  traveltime  studytime  failures    famrel  \
# 0  1.023046  1.143856  1.360371    0.792251  -0.042286 -0.449944  0.062194
# 1  0.238380 -1.600009 -1.399970   -0.643249  -0.042286 -0.449944  1.178860
# 2 -1.330954 -1.600009 -1.399970   -0.643249  -0.042286  3.589323  0.062194
# 3 -1.330954  1.143856 -0.479857   -0.643249   1.150779 -0.449944 -1.054472
# 4 -0.546287  0.229234  0.440257   -0.643249  -0.042286 -0.449944  0.062194
#
#    freetime     goout      Dalc      Walc    health  absences        G1  \
# 0 -0.236010  0.801479 -0.540699 -1.003789 -0.399289  0.036424 -1.782467
# 1 -0.236010 -0.097908 -0.540699 -1.003789 -0.399289 -0.213796 -1.782467
# 2 -0.236010 -0.997295  0.583385  0.551100 -0.399289  0.536865 -1.179147
# 3 -1.238419 -0.997295 -0.540699 -1.003789  1.041070 -0.464016  1.234133
# 4 -0.236010 -0.997295 -0.540699 -0.226345  1.041070 -0.213796 -1.480807
#
#          G2        G3    G3_CUT
# 0 -1.254791 -0.964934 -1.060026
# ...

# %%
df1.G3_CUT=dt.G3_CUT

# %%
df1.head()
# Out:
#         age      Medu      Fedu  traveltime  studytime  failures    famrel  \
# 0  1.023046  1.143856  1.360371    0.792251  -0.042286 -0.449944  0.062194
# 1  0.238380 -1.600009 -1.399970   -0.643249  -0.042286 -0.449944  1.178860
# 2 -1.330954 -1.600009 -1.399970   -0.643249  -0.042286  3.589323  0.062194
# 3 -1.330954  1.143856 -0.479857   -0.643249   1.150779 -0.449944 -1.054472
# 4 -0.546287  0.229234  0.440257   -0.643249  -0.042286 -0.449944  0.062194
#
#    freetime     goout      Dalc      Walc    health  absences        G1  \
# 0 -0.236010  0.801479 -0.540699 -1.003789 -0.399289  0.036424 -1.782467
# 1 -0.236010 -0.097908 -0.540699 -1.003789 -0.399289 -0.213796 -1.782467
# 2 -0.236010 -0.997295  0.583385  0.551100 -0.399289  0.536865 -1.179147
# 3 -1.238419 -0.997295 -0.540699 -1.003789  1.041070 -0.464016  1.234133
# 4 -0.236010 -0.997295 -0.540699 -0.226345  1.041070 -0.213796 -1.480807
#
#          G2        G3 G3_CUT
# 0 -1.254791 -0.964934      0
# ...

# %%
pd.plotting.parallel_coordinates(df1,class_column='G3_CUT',color=('red','blue'))
# Out:
# <AxesSubplot:>

# %%
pd.plotting.andrews_curves(df1,class_column='G3_CUT',color=('red','blue'))
# Out:
# <AxesSubplot:>
